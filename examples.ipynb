# %%
from todds_timer import Timer
from time import sleep
import logging

logging.basicConfig(level=logging.DEBUG, format="%(asctime)s %(levelname)s %(message)s")

@Timer("Example use as a basic decorator")
def basic_example_decorator():
    pass

@Timer("Example use as a decorator with arguments {0} and {1}")
def example_decorator_with_args(a, b):
    pass

@Timer("Example use as a decorator with kwargs {kwarg1} and {kwarg2:.2f}")
def example_decorator_with_kwargs(kwarg1=None, kwarg2=None):
    pass

@Timer("Example use with a mix of args and kwargs {0} and {kwarg1}")
def example_decorator_with_mix_args_kwargs(a, kwarg1=None):
    pass

@Timer("Example use showing timer is accurate to {0} seconds")
def example_1sec(a: int):
    sleep(a)

@Timer("Example use as decorators demonstrating indentation")
def example_decorator_with_indentation():
    basic_example_decorator()

# %%
basic_example_decorator()
# Out:
# 2025-03-12 13:25:55,807 INFO ----STARTED Example use as a basic decorator
# 2025-03-12 13:25:55,808 INFO ----COMPLETED (in 00.001 seconds) Example use as a basic decorator

# %%
example_decorator_with_args(1, 2)
# Out:
# 2025-03-12 13:25:55,840 INFO ----STARTED Example use as a decorator with arguments 1 and 2
# 2025-03-12 13:25:55,841 INFO ----COMPLETED (in 00.001 seconds) Example use as a decorator with arguments 1 and 2

# %%
example_decorator_with_kwargs(kwarg1="hello", kwarg2=3.14159)
# Out:
# 2025-03-12 13:25:55,923 INFO ----STARTED Example use as a decorator with kwargs hello and 3.14
# 2025-03-12 13:25:55,924 INFO ----COMPLETED (in 00.001 seconds) Example use as a decorator with kwargs hello and 3.14

# %%
example_decorator_with_mix_args_kwargs(1, kwarg1="hello")
# Out:
# 2025-03-12 13:25:55,988 INFO ----STARTED Example use with a mix of args and kwargs 1 and hello
# 2025-03-12 13:25:55,989 INFO ----COMPLETED (in 00.001 seconds) Example use with a mix of args and kwargs 1 and hello

# %%
# You can adjust the log level of all Timers
Timer.set_log_level(logging.INFO)

# %%
example_1sec(1)
# Out:
# 2025-03-12 13:25:56,075 INFO ----STARTED Example use showing timer is accurate to 1 seconds
# 2025-03-12 13:25:57,080 INFO ----COMPLETED (in 01.005 seconds) Example use showing timer is accurate to 1 seconds

# %%
example_decorator_with_indentation()
# Out:
# 2025-03-12 13:25:57,095 INFO ----STARTED Example use as decorators demonstrating indentation
# 2025-03-12 13:25:57,096 INFO --------STARTED Example use as a basic decorator
# 2025-03-12 13:25:57,096 INFO --------COMPLETED (in 00.001 seconds) Example use as a basic decorator
# 2025-03-12 13:25:57,097 INFO ----COMPLETED (in 00.002 seconds) Example use as decorators demonstrating indentation

# %%
with Timer("Example use as a context manager"):
    pass
# Out:
# 2025-03-12 13:25:57,118 INFO ----STARTED Example use as a context manager
# 2025-03-12 13:25:57,119 INFO ----COMPLETED (in 00.001 seconds) Example use as a context manager

# %%
with Timer("Example use as context manager indent 1"):
    with Timer("Example use as context manager indent 2"):
        pass
# Out:
# 2025-03-12 13:25:57,150 INFO ----STARTED Example use as context manager indent 1
# 2025-03-12 13:25:57,151 INFO --------STARTED Example use as context manager indent 2
# 2025-03-12 13:25:57,152 INFO --------COMPLETED (in 00.001 seconds) Example use as context manager indent 2
# 2025-03-12 13:25:57,153 INFO ----COMPLETED (in 00.003 seconds) Example use as context manager indent 1

# %%
some_function = lambda x, y: logging.info(f"Hello {x}{y}")
function_args = ("world", "!")
with Timer("Example use as context manager with args {0} and {1}", args=function_args):
    some_function(*function_args)
# Out:
# 2025-03-12 13:25:57,246 INFO ----STARTED Example use as context manager with args world and !
# 2025-03-12 13:25:57,247 INFO Hello world!
# 2025-03-12 13:25:57,247 INFO ----COMPLETED (in 00.002 seconds) Example use as context manager with args world and !

# %%
Timer.print_average_times(number_pad_character="0")
# Out:
# 2025-03-12 13:25:57,265 INFO  Average | Minimum | Maximum | Count | Task
# 2025-03-12 13:25:57,266 INFO  000.001 | 000.001 | 000.001 | 00004 | Example use as a basic decorator
# 2025-03-12 13:25:57,267 INFO  000.001 | 000.001 | 000.001 | 00002 | Example use as a decorator with arguments {0} and {1}
# 2025-03-12 13:25:57,268 INFO  000.001 | 000.001 | 000.001 | 00002 | Example use as a decorator with kwargs {kwarg1} and {kwarg2:.2f}
# 2025-03-12 13:25:57,269 INFO  000.001 | 000.001 | 000.001 | 00002 | Example use with a mix of args and kwargs {0} and {kwarg1}
# 2025-03-12 13:25:57,269 INFO  001.003 | 001.001 | 001.005 | 00002 | Example use showing timer is accurate to {0} seconds
# 2025-03-12 13:25:57,270 INFO  000.002 | 000.002 | 000.002 | 00002 | Example use as decorators demonstrating indentation
# 2025-03-12 13:25:57,271 INFO  000.001 | 000.001 | 000.001 | 00002 | Example use as a context manager
# 2025-03-12 13:25:57,271 INFO  000.001 | 000.001 | 000.001 | 00002 | Example use as context manager indent 2
# 2025-03-12 13:25:57,272 INFO  000.003 | 000.003 | 000.003 | 00002 | Example use as context manager indent 1
# 2025-03-12 13:25:57,273 INFO  000.001 | 000.001 | 000.002 | 00003 | Example use as context manager with args {0} and {1}
